# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
activity = pd.read_csv('ACTIVITY/data.csv')
activity
# Out:
#            date  lastSyncTime  steps  distance  runDistance  calories
# 0    2019-12-16    1576546186   7055      4954          353       154
# 1    2019-12-17    1576630404   6796      4674          215       143
# 2    2019-12-18    1576716319   6485      4472          214       137
# 3    2019-12-19    1576804172   8688      5948          302       183
# 4    2019-12-20    1576866636   6511      4531          261       141
# ..          ...           ...    ...       ...          ...       ...
# 225  2020-04-06    1586197897   1833      1251          146        43
# 226  2020-04-07    1586285521    982       664          127        25
# 227  2020-04-08    1586404037   1258       851          107        30
# 228  2020-04-09    1586491334   1313       889           86        33
# 229  2020-04-10    1586576546   1596      1080          138        38
#
# [230 rows x 6 columns]

# %%
nosteps = activity['steps']>100
steps = activity.loc[nosteps,'steps']
days = len(steps)
print(steps)
# Out:
# 0      7055
# 1      6796
# 2      6485
# 3      8688
# 4      6511
#        ...
# 225    1833
# 226     982
# 227    1258
# 228    1313
# 229    1596
# Name: steps, Length: 198, dtype: int64

# %%
plt.figure(figsize=(15,7))
plt.plot(np.arange(days),steps)
plt.grid(True)
plt.xlabel('Days')
plt.ylabel('Number of steps')
plt.title('Steps Analysis')
plt.savefig('steps.png')
